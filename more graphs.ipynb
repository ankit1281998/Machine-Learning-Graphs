# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
pwd=os.getcwd()
data=pd.read_csv(pwd+"//netflix_titles.csv")
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data["date col"]=pd.to_datetime(data["date_added"])
data["month"]=data["date col"].dt.month
data["year"]=data["date col"].dt.year
data["day"]=data["date col"].dt.day

# %%
data.plot()
# Out:
# <Axes: >

# %%
data["year"].plot()
# Out:
# <Axes: >

# %%
data["year"][6000:6100].plot(figsize=(14,6))
# Out:
# <Axes: >

# %%
data["day"][3000:3010].plot()
data["month"][3000:3010].plot()
# Out:
# <Axes: >

# %%
calc=data["month"]+data["day"]
calc
# Out:
# 0       34.0
# 1       33.0
# 2       33.0
# 3       33.0
# 4       33.0
#         ...
# 8802    31.0
# 8803     8.0
# 8804    12.0
# 8805    12.0
# 8806     5.0
# Length: 8807, dtype: float64

# %%
calc=calc[0:500]

# %%
calc
# Out:
# 0      34.0
# 1      33.0
# 2      33.0
# 3      33.0
# 4      33.0
#        ...
# 495    14.0
# 496    14.0
# 497    14.0
# 498    14.0
# 499    14.0
# Length: 500, dtype: float64

# %%
calc[0:50].plot(kind="bar",title="random graph")
# Out:
# <Axes: title={'center': 'random graph'}>

# %%
data=data.dropna()

# %%
data2=data[0:4]
data2
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                      United Kingdom  September 24, 2021
# 9                                       United States  September 24, 2021
# ...

# %%
data2.plot("release_year","day")
# Out:
# <Axes: xlabel='release_year'>

# %%
plt.plot(calc)

# %%
plt.plot(calc,marker="o")

# %%
calc.plot(marker="o")
# Out:
# <Axes: >

# %%
plt.plot(data["release_year"])

# %%
plt.plot(data["year"],data["release_year"],marker="o")

# %%
#data[['year', 'month']].plot()
data2[["day","month"]].plot()
# Out:
# <Axes: >

# %%
plt.plot(data2["day"],marker="o",color="red",linestyle="--",linewidth=1,ms=8,mew=2,mec="navy",alpha=0.75)
plt.plot(data2["month"],"x--b")    # marker,linestyle,color

plt.title("random graph")
plt.legend(["month","day"])
plt.xlabel("month")
plt.ylabel=("day")

# %%
plt.figure(figsize=(4,2))
plt.plot(data2["month"],"xb")

# %%
plt.figure(figsize=(4,2))
plt.plot(data2["month"])

# %%
sns.set_style("whitegrid")

# %%
plt.plot(data2["day"],marker="o",color="red",linestyle="--",linewidth=1,ms=8,mew=2,mec="navy",alpha=0.75)
plt.plot(data2["month"],"x--b")    # marker,linestyle,color

plt.title("random graph")
plt.legend(["month","day"])
plt.xlabel("month")
plt.ylabel=("day")

# %%
sns.set_style("darkgrid")
plt.plot(data2["day"],marker="o",linestyle="--",linewidth=1,ms=8,mew=2,mec="navy",alpha=0.75)
plt.plot(data2["month"],"x--")    # marker,linestyle,color

plt.title("random graph")
plt.legend(["month","day"])
plt.xlabel("month")
plt.ylabel=("day")

# %%
import matplotlib
matplotlib.rcParams["font.size"]=14

# %%
plt.plot(data2["day"],marker="o",linestyle="--",linewidth=1,ms=8,mew=2,mec="navy",alpha=0.75)
plt.plot(data2["month"],"x--")    # marker,linestyle,color

plt.title("random graph")
plt.legend(["month","day"])
plt.xlabel("month")
plt.ylabel=("day")

# %% [markdown]
# Multiple graphs

# %%
Y=[2,3,4,5,6]
Y2=[3,6,3,6,7]
Y3=[2,6,7,2,3]

# %%
flights=sns.load_dataset("flights").pivot("month","year","passengers")
flights
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_2320\2442886198.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights=sns.load_dataset("flights").pivot("month","year","passengers")
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# ...

# %%
from urllib.request import urlretrieve
urlretrieve("https://i.imgur.com/SkPbq.jpg","image.jpg")
# Out:
# ('image.jpg', <http.client.HTTPMessage at 0x1def277acd0>)

# %%
from PIL import Image
img=Image.open("image.jpg")

# %%
plt.imshow(img)

# %%
plt.subplots(2,3)
# Out:
# (<Figure size 640x480 with 6 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %%
fig,axes=plt.subplots(2,3,figsize=(12,9))

plt.tight_layout(pad=2)

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
axes.shape
# Out:
# (2, 3)

# %%
axes[0,0]
# Out:
# <Axes: >

# %%
fig,axes=plt.subplots(2,3,figsize=(12,9))
axes[0,0].plot(Y,Y2,"o--r")
axes[0,0].plot(Y,Y3,"s--b")
axes[0,0].set_title("graph1")
axes[0,0].set_xlabel("x")
axes[0,0].set_xlabel("y")
axes[0,0].legend(["x","y"])

axes[0,1].set_title("graph2")
sns.scatterplot(x=Y,y=Y2,hue=Y3,s=100,ax=axes[0,1])

axes[0,2].set_title("graph3")
axes[0,2].hist([Y2,Y3],stacked=True)
axes[0,2].legend(["Y2","Y3"])

axes[1,0].set_title("graph4")
axes[1,0].bar(Y,Y3)

axes[1,1].set_title("graph5")
sns.heatmap(flights,cmap="Blues",ax=axes[1,1])

axes[1,2].set_title("graph6")
axes[1,2].imshow(img)
axes[1,2].axis("off")
#axes[1,2].set_xticks([])
#axes[1,2].set_yticks([])

plt.tight_layout(pad=2)
