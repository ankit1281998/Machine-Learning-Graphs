# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
pwd=os.getcwd()
data_import=pd.read_csv(pwd+"//netflix_titles.csv",parse_dates=["date_added"])  #date_added column is parsed as dates.
data_import
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data=data_import.copy()
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
data.head()   # first 5 rows
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
data.tail()   #last 5 rows
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 8802 2019-11-20          2007      R    158 min
# 8803 2019-07-01          2018  TV-Y7  2 Seasons
# 8804 2019-11-01          2009      R     88 min
# ...

# %%
data.shape  # shape of data
# Out:
# (8807, 12)

# %%
data.info()    # info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
data.count()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data["release_year"].describe()
# Out:
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
data["release_year"].mean()
# Out:
# 2014.1801975701146

# %%
data["release_year"].median()
# Out:
# 2017.0

# %%
data["release_year"].plot(kind="box", vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
data["release_year"].hist()
# Out:
# <Axes: >

# %%
data["release_year"].plot(kind="bar", figsize=(14,6))
# Out:
# <Axes: >

# %%
data=data_import.copy()
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data["release_year"].plot(kind="density", figsize=(14,6))

# %%
ax=data["release_year"].plot(kind="hist", figsize=(14,4))
ax.set_ylabel("movies")
ax.set_xlabel("year")
# Out:
# Text(0.5, 0, 'year')

# %%
#Categorical analysis and visualization

data["type"].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
data["release_year"].value_counts().plot(kind="pie",figsize=(4,4))
# Out:
# <Axes: ylabel='release_year'>

# %%
data["type"].value_counts().plot(kind="pie",figsize=(4,4))
# Out:
# <Axes: ylabel='type'>

# %%
data["release_year"].value_counts().plot(kind="bar",figsize=(10,4))
# Out:
# <Axes: >

# %%
data["type"].value_counts().plot(kind="bar",figsize=(4,4))
# Out:
# <Axes: >

# %%
corr=data.corr()
corr
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_16128\2248884307.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data.corr()
#               release_year
# release_year           1.0

# %%
data.plot(kind="scatter", figsize=(14,4),x="release_year",y="date_added") 
# scatter plots are made on numerical values mostly(x and y arguments and drawn only on dataframe)
# Out:
# <Axes: xlabel='release_year', ylabel='date_added'>

# %%
data[data["release_year"]==2008]
# Out:
#      show_id   type                              title  \
# 57       s58  Movie  Naruto Shippûden the Movie: Bonds
# 167     s168  Movie                      Open Season 2
# 182     s183  Movie        Welcome Home Roscoe Jenkins
# 188     s189  Movie                   2 Alone in Paris
# 192     s193  Movie                         C Kkompany
# ...      ...    ...                                ...
# 8615   s8616  Movie                            Traitor
# 8651   s8652  Movie                              Tyson
# 8670   s8671  Movie                      Vantage Point
# 8769   s8770  Movie             Y.M.I.: Yeh Mera India
# 8790   s8791  Movie      You Don't Mess with the Zohan
#
#                                  director  \
# 57                        Hajime Kamegaki
# 167   Matthew O'Callaghan, Todd Wilderman
# 182                        Malcolm D. Lee
# 188               Ramzy Bedia, Éric Judor
# 192                          Sachin Yardi
# ...                                   ...
# ...

# %%
data[data["release_year"]==2008].count()
# Out:
# show_id         136
# type            136
# title           136
# director        112
# cast            135
# country         132
# date_added      135
# release_year    136
# rating          136
# duration        136
# listed_in       136
# description     136
# dtype: int64

# %%
data[data["release_year"]==2008]["type"].count()
# Out:
# 136

# %%
data[data["release_year"]==2020].sum()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_16128\3249352450.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data[data["release_year"]==2020].sum()
# show_id         s1s17s18s33s35s48s79s85s104s120s127s149s190s22...
# type            MovieMovieTV ShowTV ShowTV ShowTV ShowMovieMov...
# title           Dick Johnson Is DeadEurope's Most Dangerous Ma...
# release_year                                              1925060
# rating          PG-13TV-MATV-MATV-MATV-Y7TV-MATV-14TV-MATV-MAT...
# duration        90 min67 min2 Seasons3 Seasons1 Season1 Season...
# listed_in       DocumentariesDocumentaries, International Movi...
# description     As her father nears the end of his life, filmm...
# dtype: object

# %%
data[data["release_year"]==2008].shape[0]
# Out:
# 136

# %%
data[data["release_year"]==2008]["type"]
# Out:
# 57      Movie
# 167     Movie
# 182     Movie
# 188     Movie
# 192     Movie
#         ...
# 8615    Movie
# 8651    Movie
# 8670    Movie
# 8769    Movie
# 8790    Movie
# Name: type, Length: 136, dtype: object

# %%
data[data["release_year"]==2008]["title"].unique()
# Out:
# array(['Naruto Shippûden the Movie: Bonds', 'Open Season 2',
#        'Welcome Home Roscoe Jenkins', '2 Alone in Paris', 'C Kkompany',
#        'EMI: Liya Hai To Chukana Padega',
#        'Mission Istaanbul: Darr Ke Aagey Jeet Hai', "You're My Destiny",
#        'Pineapple Express', 'Twilight', 'Kung Fu Panda', 'Seven Pounds',
#        'The Strangers', 'Felon', 'Never Back Down',
#        'Zack and Miri Make a Porno', 'Jaane Tu... Ya Jaane Na',
#        'Wild Child', 'Yes Man', 'Tony Manero', 'This Is the Life',
#        'ICarly', 'The Bank Job', 'A Very Special Love', 'Prom Night',
#        'Golmaal Returns', 'Sex Drive', 'Toradora!', 'Menahi',
#        'Andaleeb El Dokki', 'Sorry To Disturb', 'My Sleeping Lover',
#        'Madagascar: Escape 2 Africa', 'Boushkash', 'The Promise',
#        'Dostana', "DreamWorks Shrek's Swamp Stories", 'Soul Eater',
#        "Garfield's Fun Fest", 'Rock On!!', 'Defiance',
# ...

# %%
data["type"].values
# Out:
# array(['Movie', 'TV Show', 'TV Show', ..., 'Movie', 'Movie', 'Movie'],
#       dtype=object)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
data.loc[2008]
# Out:
# show_id                                                     s2009
# type                                                      TV Show
# title                                             Family Business
# director                                                      NaN
# cast            Jonathan Cohen, Gérard Darmon, Julia Piaton, L...
# country                                                    France
# date_added                                    2020-09-11 00:00:00
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in          International TV Shows, TV Comedies, TV Dramas
# description     After learning France is about to legalize pot...
# Name: 2008, dtype: object

# %%
data.loc[1]
# Out:
# show_id                                                        s2
# type                                                      TV Show
# title                                               Blood & Water
# director                                                      NaN
# cast            Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# country                                              South Africa
# date_added                                    2021-09-24 00:00:00
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in         International TV Shows, TV Dramas, TV Mysteries
# description     After crossing paths at a party, a Cape Town t...
# Name: 1, dtype: object

# %%
data2=data.copy()
data2
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data2.index=data["show_id"]

# %%
data2
# Out:
#         show_id     type                  title         director  \
# show_id
# s1           s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2           s2  TV Show          Blood & Water              NaN
# s3           s3  TV Show              Ganglands  Julien Leclercq
# s4           s4  TV Show  Jailbirds New Orleans              NaN
# s5           s5  TV Show           Kota Factory              NaN
# ...         ...      ...                    ...              ...
# s8803     s8803    Movie                 Zodiac    David Fincher
# s8804     s8804  TV Show            Zombie Dumb              NaN
# s8805     s8805    Movie             Zombieland  Ruben Fleischer
# s8806     s8806    Movie                   Zoom     Peter Hewitt
# s8807     s8807    Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# ...

# %%
data2=data2.drop("show_id",axis=1)
data2
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data2.loc["s2"]
# Out:
# type                                                      TV Show
# title                                               Blood & Water
# director                                                      NaN
# cast            Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# country                                              South Africa
# date_added                                    2021-09-24 00:00:00
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in         International TV Shows, TV Dramas, TV Mysteries
# description     After crossing paths at a party, a Cape Town t...
# Name: s2, dtype: object

# %%
data2.iloc[1]
# Out:
# type                                                      TV Show
# title                                               Blood & Water
# director                                                      NaN
# cast            Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# country                                              South Africa
# date_added                                    2021-09-24 00:00:00
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in         International TV Shows, TV Dramas, TV Mysteries
# description     After crossing paths at a party, a Cape Town t...
# Name: s2, dtype: object

# %%
data2["director"].dropna()
# Out:
# show_id
# s1                     Kirsten Johnson
# s3                     Julien Leclercq
# s6                       Mike Flanagan
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
#                      ...
# s8802                  Majid Al Ansari
# s8803                    David Fincher
# s8805                  Ruben Fleischer
# s8806                     Peter Hewitt
# s8807                      Mozez Singh
# Name: director, Length: 6173, dtype: object

# %%
data2.dropna(how="all")
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data2[["director","country"]].dropna()
# Out:
#                     director  \
# show_id
# s1           Kirsten Johnson
# s8              Haile Gerima
# s9           Andy Devonshire
# s10           Theodore Melfi
# s13      Christian Schwochow
# ...                      ...
# s8802        Majid Al Ansari
# s8803          David Fincher
# s8805        Ruben Fleischer
# s8806           Peter Hewitt
# s8807            Mozez Singh
#
#                                                    country
# show_id
# s1                                           United States
# s8       United States, Ghana, Burkina Faso, United Kin...
# s9                                          United Kingdom
# s10                                          United States
# s13                                Germany, Czech Republic
# ...                                                    ...
# s8802                         United Arab Emirates, Jordan
# s8803                                        United States
# ...

# %%
data2.drop("s1")
# Out:
#             type                  title         director  \
# show_id
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# s6       TV Show          Midnight Mass    Mike Flanagan
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
data2[["director","country"]]
# Out:
#                 director        country
# show_id
# s1       Kirsten Johnson  United States
# s2                   NaN   South Africa
# s3       Julien Leclercq            NaN
# s4                   NaN            NaN
# s5                   NaN          India
# ...                  ...            ...
# s8803      David Fincher  United States
# s8804                NaN            NaN
# s8805    Ruben Fleischer  United States
# s8806       Peter Hewitt  United States
# s8807        Mozez Singh          India
#
# [8807 rows x 2 columns]

# %%
data2["type"]
# Out:
# show_id
# s1         Movie
# s2       TV Show
# s3       TV Show
# s4       TV Show
# s5       TV Show
#           ...
# s8803      Movie
# s8804    TV Show
# s8805      Movie
# s8806      Movie
# s8807      Movie
# Name: type, Length: 8807, dtype: object

# %%
data2["type"]+" "+ data2["title"]
# Out:
# show_id
# s1          Movie Dick Johnson Is Dead
# s2               TV Show Blood & Water
# s3                   TV Show Ganglands
# s4       TV Show Jailbirds New Orleans
# s5                TV Show Kota Factory
#                      ...
# s8803                     Movie Zodiac
# s8804              TV Show Zombie Dumb
# s8805                 Movie Zombieland
# s8806                       Movie Zoom
# s8807                     Movie Zubaan
# Length: 8807, dtype: object

# %%
data2.head(2)
# Out:
#             type                 title         director  \
# show_id
# s1         Movie  Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show         Blood & Water              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#         date_added  release_year rating   duration  \
# show_id
# s1      2021-09-25          2020  PG-13     90 min
# s2      2021-09-24          2021  TV-MA  2 Seasons
#
#                                                listed_in  \
# show_id
# s1                                         Documentaries
# s2       International TV Shows, TV Dramas, TV Mysteries
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...

# %%
data3=data.copy()
data3
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data3.set_index("show_id")
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data3
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...
