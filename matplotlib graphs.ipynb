# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
pwd=os.getcwd()
df=pd.read_csv(pwd+"//netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df["date col"]=pd.to_datetime(df["date_added"])
df["month"]=df["date col"].dt.month
df["year"]=df["date col"].dt.year
df["day"]=df["date col"].dt.day
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
plt.plot(df.index,df["release_year"])

# %%
x=np.arange(-10,11)
plt.plot(x,x**2)

# %%
df.loc[2000:2050].plot()
# Out:
# <Axes: >

# %%
x=np.arange(-10,11)
plt.figure(figsize=(8,4))
plt.plot(x,x**2,linestyle="--",c="red",marker="o",linewidth="2")
plt.legend(["x","x^2"])
plt.xlabel("x")
plt.ylabel("x^2")
# Out:
# Text(0, 0.5, 'x^2')

# %%
n=50
x=np.random.rand(n)
y=np.random.rand(n)
colors=np.random.rand(n)
area=np.pi* (20*np.random.rand(n))**2

# %%
x
# Out:
# array([0.32955359, 0.32829301, 0.2895987 , 0.78934041, 0.90562773,
#        0.16170587, 0.05557101, 0.80242289, 0.01925976, 0.64723258,
#        0.88400143, 0.2725958 , 0.22377147, 0.46886597, 0.25520254,
#        0.53638426, 0.66108888, 0.74174804, 0.14839143, 0.08999055,
#        0.09771932, 0.17421587, 0.53477077, 0.86546837, 0.70340696,
#        0.84164307, 0.37499716, 0.97224825, 0.18629952, 0.29242714,
#        0.09010783, 0.43034003, 0.47474974, 0.40765152, 0.47261589,
#        0.38125678, 0.7818365 , 0.56942581, 0.48330848, 0.63636489,
#        0.90559967, 0.49275389, 0.58952834, 0.21896058, 0.72793015,
#        0.44607782, 0.87188139, 0.64690339, 0.70140931, 0.66068437])

# %%
area
# Out:
# array([5.92624913e+02, 3.91449691e+02, 1.07129899e+03, 3.51543503e+02,
#        4.29506501e+02, 2.71682040e+02, 1.00773122e+03, 9.91153898e+00,
#        9.64118300e+02, 2.30961340e-02, 7.05850676e+02, 3.90033619e-02,
#        1.36295590e+02, 2.00630360e+02, 1.19951469e+02, 7.62501310e+01,
#        2.00284210e+02, 5.57850512e+01, 1.14453497e+03, 1.09535226e+03,
#        2.18145900e+02, 8.03478502e+02, 1.25978788e+02, 1.35661860e+02,
#        2.09137560e+01, 3.67325632e+01, 2.04021027e+02, 1.38207832e+02,
#        8.59543968e-01, 6.74045195e+01, 6.34041373e+02, 6.31959660e+01,
#        3.65535240e+02, 9.95075554e+02, 4.23524946e+01, 1.09736681e+03,
#        6.53910145e+00, 1.55226812e+02, 3.19187568e+02, 7.46908240e+00,
#        1.71235670e+02, 7.14036547e-01, 7.26971493e+02, 5.01300672e+02,
#        3.58442902e+01, 1.57130002e+02, 3.79363687e+01, 9.24929597e+00,
#        8.91753205e+02, 8.11859828e+00])

# %%
plt.figure(figsize=(8,4))
plt.scatter(x,y,s=area,c=colors,alpha=0.8,cmap="Spectral")
plt.colorbar()

# %%
plt.figure(figsize=(8,4))
plt.scatter(x,y,area,colors,alpha=0.8,cmap="Spectral")
plt.colorbar()

# %%
plt.figure(figsize=(8,4))
plt.scatter(x,y,colors,area,alpha=0.8,cmap="Spectral")
plt.colorbar()

# %%
values=np.random.randn(1000)

# %%
plt.hist(values,bins=10,alpha=0.8,histtype="bar",color="red",edgecolor="green")
# Out:
# (array([1., 1., 0., 0., 4., 6., 0., 0., 1., 1.]),
#  array([-15., -12.,  -9.,  -6.,  -3.,   0.,   3.,   6.,   9.,  12.,  15.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(values,bins=10,alpha=0.8,histtype="bar",color="red",edgecolor="green")
plt.xlim(xmin=-10,xmax=10)
plt.show()
#plt.savefig("hist.png")

# %%
x=np.arange(-10,11)
plt.figure(figsize=(8,4))
plt.plot(x,x**2,linestyle="--",c="blue",marker="o",linewidth="2")

plt.hist(values,bins=10,alpha=0.8,histtype="bar",color="red",edgecolor="green")
# Out:
# (array([  2.,   7.,  46., 147., 259., 278., 177.,  70.,  11.,   3.]),
#  array([-3.79118038, -3.04806637, -2.30495237, -1.56183837, -0.81872436,
#         -0.07561036,  0.66750364,  1.41061765,  2.15373165,  2.89684565,
#          3.63995965]),
#  <BarContainer object of 10 artists>)

# %%
#Bar Plot
Y=np.random.rand(5)
Y2=np.random.rand(5)

# %%
plt.figure(figsize=(12,4))
barWidth=0.3

plt.bar(np.arange(len(Y)),Y,width=barWidth,color="blue")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(12,4))
barWidth=0.3

plt.bar(np.arange(len(Y)),Y,width=barWidth,color="blue",label="Y")

plt.bar(np.arange(len(Y2)),Y2,width=barWidth,color="orange",label="Y2")
plt.legend()
#plt.show()

# %%
plt.figure(figsize=(12,4))
barWidth=0.3

plt.bar(np.arange(len(Y)),Y,width=barWidth,color="blue",label="Y")

plt.bar(np.arange(len(Y2)),Y2,width=barWidth,color="orange",bottom=Y,label="Y2")
plt.legend()
plt.show()

# %%
#plt.savefig("pic.png")

# %%
#Boxtplots and outliers detecters
values=np.concatenate([np.random.randn(10),np.array([10,15,-10,-15])])

# %%
values
# Out:
# array([  0.49093835,   0.05061733,   0.57921198,   1.49776545,
#         -0.73068893,   1.04928261,  -1.67705862,  -0.33834381,
#          1.35724591,  -0.74466507,  10.        ,  15.        ,
#        -10.        , -15.        ])

# %%
plt.figure(figsize=(12,4))
plt.hist(values)
# Out:
# (array([1., 1., 0., 0., 4., 6., 0., 0., 1., 1.]),
#  array([-15., -12.,  -9.,  -6.,  -3.,   0.,   3.,   6.,   9.,  12.,  15.]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12,4))
plt.boxplot(values,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a166d24d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a166d033d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a166b38070>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a166b565b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a166b561c0>],
#  'means': []}

# %%
df["date_added"][0]
# Out:
# 'September 25, 2021'

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[df["type"].str.contains("TV")]["day"].mean()
# Out:
# day    13.448987
# dtype: float64

# %%
df["weekday"]=df["date col"].dt.weekday

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.sum()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_6180\1703867807.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sum()
# show_id         s1s2s3s4s5s6s7s8s9s10s11s12s13s14s15s16s17s18s...
# type            MovieTV ShowTV ShowTV ShowTV ShowTV ShowMovieM...
# title           Dick Johnson Is DeadBlood & WaterGanglandsJail...
# release_year                                             17738885
# listed_in       DocumentariesInternational TV Shows, TV Dramas...
# description     As her father nears the end of his life, filmm...
# month                                                     58544.0
# year                                                   17760016.0
# day                                                      109939.0
# ...
